# %% [markdown]
# ### Web Scrapper

# %%
import requests
from parsel import Selector
import urllib.parse
import re
import json

def extract_pagename(hotel_url):
    """Extract the pagename from a Booking.com hotel URL"""
    parsed = urllib.parse.urlparse(hotel_url)
    path = parsed.path
    # Example: /hotel/in/trident-nariman-point.html
    match = re.search(r'/hotel/.+?/(.+?)\.html', path)
    return match.group(1) if match else None

def get_review_page_html(pagename, offset=0, rows=10, country_code='in', lang='en-us'):
    """Download raw review page HTML"""
    base = "https://www.booking.com/reviewlist.html"
    params = {
        'cc1': country_code,
        'lang': lang,
        'pagename': pagename,
        'rows': rows,
        'offset': offset,
        'type': 'total',
        'sort': 'f_recent_desc'
    }
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
    }
    response = requests.get(base, params=params, headers=headers)
    response.raise_for_status()
    return response.text

def parse_reviews(html):
    """Parse review page HTML into structured reviews"""
    selector = Selector(text=html)
    reviews = []
    for review in selector.css('.review_list_new_item_block'):
        get = lambda sel: review.css(sel).get(default='').strip()
        get_all = lambda sel: ' '.join([t.strip() for t in review.css(sel).getall()]).strip()

        reviews.append({
            'score': get('.bui-review-score__badge::text'),
            'title': get('.c-review-block__title::text'),
            'date': get('.c-review-block__date::text'),
            'user_name': get('.bui-avatar-block__title::text'),
            'user_country': get('.bui-avatar-block__subtitle::text'),
            'text': get_all('.c-review__body ::text'),
            'lang': get('.c-review__body::attr(lang)')
        })
    return reviews

def scrape_all_reviews(hotel_url, max_pages=2):
    pagename = extract_pagename(hotel_url)
    if not pagename:
        raise ValueError("Could not extract pagename from URL")

    print(f"Scraping reviews for pagename: {pagename}")

    all_reviews = []
    for page in range(max_pages):
        offset = page * 10
        html = get_review_page_html(pagename, offset=offset)
        reviews = parse_reviews(html)
        if not reviews:
            break
        all_reviews.extend(reviews)
        print(f"Scraped {len(reviews)} reviews from page {page+1}")

    return all_reviews

# EXAMPLE USE
if __name__ == '__main__':
    HOTEL_URL = 'https://www.booking.com/hotel/in/trident-nariman-point.html'
    reviews = scrape_all_reviews(HOTEL_URL, max_pages=10)

    print(json.dumps(reviews, indent=2, ensure_ascii=False))
# Out:
# Scraping reviews for pagename: trident-nariman-point
# Scraped 10 reviews from page 1
# Scraped 10 reviews from page 2
# Scraped 10 reviews from page 3
# Scraped 10 reviews from page 4
# Scraped 10 reviews from page 5
# Scraped 10 reviews from page 6
# Scraped 10 reviews from page 7
# Scraped 10 reviews from page 8
# Scraped 10 reviews from page 9
# Scraped 10 reviews from page 10
# [
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "July 2025",
#     "user_name": "Mouri",
#     "user_country": "Bangladesh",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Cassandra",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Anonymous",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "July 2025",
#     "user_name": "Tomás",
#     "user_country": "Portugal",
#     "text": "La atención del personal del hotel es impecable. Siempre atentos y disponibles para que la estadía sea lo más cómoda posible.",
#     "lang": "es"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Tilekar",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Bashayer",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Mandar",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Monika",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "July 2025",
#     "user_name": "Sujay",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "اتمني لكم التوفيق",
#     "date": "July 2025",
#     "user_name": "4",
#     "user_country": "United Arab Emirates",
#     "text": "جميع الخدمات كل شي ممتاز",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Manish",
#     "user_country": "India",
#     "text": "Location with great staff to help you and listen to your request Bit expensive for a non sea facing room",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Ahmad",
#     "user_country": "Kuwait",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Ahmed",
#     "user_country": "South Africa",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "شكرا لكل موظف",
#     "date": "June 2025",
#     "user_name": "Jassem",
#     "user_country": "United Arab Emirates",
#     "text": "كل شي كل شي اعجبني",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "July 2025",
#     "user_name": "Tomás",
#     "user_country": "Portugal",
#     "text": "There are no comments available for this review",
#     "lang": "es"
#   },
#   {
#     "score": "9.0",
#     "title": "فندق رائع وسأكرر التجربه",
#     "date": "June 2025",
#     "user_name": "Fahad",
#     "user_country": "United Arab Emirates",
#     "text": "الاستقبال وكذلك نظافة الفندق وتنوع المرافق يوجد عدد 2 من المطاعم تحت اللوبي و الدرج الذي يؤدي إلى المطاعم السجاد باللون الأسود يصعب رؤيته على كبار السن لابد من تغيرة او وضع لون آخر كاللون الأحمر وكذلك لا يوجد مصعد للنزول إلى هذه المطاعم تحت",
#     "lang": "ar"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Rashi",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "April 2025",
#     "user_name": "Ashna",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Abhijit",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Vishnu",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Omar",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "اقامة رائعة وطاقم متعاون",
#     "date": "June 2025",
#     "user_name": "Ibrahim",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Ibrahim",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "1.0",
#     "title": "Bad",
#     "date": "June 2025",
#     "user_name": "Randhir",
#     "user_country": "India",
#     "text": "I wrote this to their management. Received the feedback in person and on phone calls.\n1) I checked in on 05-06-2025: I was literally shocked with the behaviour of chauffeurs at the main gate who didn’t bother to help with the luggage and despite asking for help, I had pick up my luggage despite asking for help. This was around 2347 hours. I mentioned the issue at the check-in counter. I somehow let it go, as I may understand that your personnel might be busy. I felt odd but as mentioned, I let it go.\n2) On 06-Jun-2025: I had dinner in Frangpani restaurant and ordered mutton kala sukkha (something like that) and risotto. I got mostly bones in the mutton and risotto was absolutely not up to the mark. The issue was notified and the chef acknowledged the shortcomings and offered a discount. However, me and my partner refused not to accept the discount, as we were there for quality time. My objective was to send a feedback so that they do not ruin other customer’s moment of leisure. I let it go.\n3) On 07-06-2025, 2 incidents happened:\ni) During the breakfast time at Maxican Room, your employee passed on a racist comment targeting my partner among his colleague which I overheard. This was unacceptable and at this moment, I couldn’t let it go. I reported it.\nYour employee accepted what he said and apologised but it ruined the entire feel of having a quality time at your 5 star hotel.\nii) I ordered food at 21:00 hours for Dinner and the entire order came in parts, first part came in 30-40 min post ordering ( I also informed the in-house dinning guy that I will be waiting for the second part). The second part of the order came at 2230 hours. I had to return the order as the first part got cold and the quality has been reduced as expected. The manager confirmed that they missed it. My partner and me had to return back without food and due to late arrival of meal my partner had minor gastrointestinal issues, which is being taken care now.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Purnima",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "ممتاز",
#     "date": "June 2025",
#     "user_name": "Omar",
#     "user_country": "United Arab Emirates",
#     "text": "كل شي جميل في الفندق باختصار اقامة رائعه",
#     "lang": "ar"
#   },
#   {
#     "score": "7.0",
#     "title": "Good",
#     "date": "June 2025",
#     "user_name": "Praveen",
#     "user_country": "United Kingdom",
#     "text": "Good sized room and decent bathroom\rGood location, now that the coastal road is operational\rDecent breakfast Not enough sitting space in the lobby\rNo place to have a cigar in the evening\rRoom card sokmetimes didnt work well in the lift\rFlush didnt work well in the room; had to call housekeeping to fix",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Can highly recommend this place. One of the best experiences I ever had. Super friendly and professional staff, good foo",
#     "date": "June 2025",
#     "user_name": "Claudia",
#     "user_country": "Switzerland",
#     "text": "Service, Freundlichkeit des Personals, Spa",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Amol",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Khan",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Will be back again.",
#     "date": "June 2025",
#     "user_name": "Vandhana",
#     "user_country": "United Arab Emirates",
#     "text": "Everything was great. We celebrated my husband's 60th birthday and they went out of their way to make it special for him. Nothing",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Abdulla",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Amresh",
#     "user_country": "Netherlands",
#     "text": "Location is perfect.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Stay soon .",
#     "date": "June 2025",
#     "user_name": "Laxmi",
#     "user_country": "India",
#     "text": "Hotel  view  is Very to closed to Nature and Ocean 🌊 so I very like it. Nothing",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Irfan",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Ashish",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "I will go back again",
#     "date": "June 2025",
#     "user_name": "Vandhana",
#     "user_country": "United Arab Emirates",
#     "text": "Excellent spread of indian and continental breakfast Service ans staff",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Saurabh",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Majed",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Sherzad",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Great location. Comfortable and excellent service",
#     "date": "June 2025",
#     "user_name": "Jonas",
#     "user_country": "Bahrain",
#     "text": "The room was very comfortable and service was excellent. The location is great as south Mumbai has very little traffic congestion and it's ready to get to a large variety of restaurants and other entertainment. I had to pay for scanning a few documents at the business center. It didn't cost much, but it surprised me that a 5 star hotel does not provide this service",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Anvi",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Viren",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "10/10 hotel experience.",
#     "date": "June 2025",
#     "user_name": "Thabit",
#     "user_country": "Oman",
#     "text": "I would like to extend my thanks for all Trident staff I have enjoyed my stay at this hotel. The staff were warm, friendly, and very welcoming, they helped me in everything I needed help with throughout my stay. The rooms were cozy and comfortable, a perfect environment to rest in. The breakfast was very delicious and the options were plenty. I genuinely enjoyed my stay here and I would definitely recommend visiting/staying here.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Ashish",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Anonymous",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Keshav",
#     "user_country": "India",
#     "text": "India Jones has a fantastic staff, especially chef Gauravi, Stefan, and Avipura. They really went the extra mile to make sure breakfast was perfect.",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Sumant",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Bharat",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Amazing stay and will revisit!",
#     "date": "June 2025",
#     "user_name": "Sharda",
#     "user_country": "Thailand",
#     "text": "Very relaxed atmosphere. Not stuffy at all as some 5 star hotels can be. Staff was excellent. Courteous, attentive and efficient.\nMy room was spotless. Plenty of towels, which was wonderful.\nVery receptive to my request not to have my room cleaned for the 4 nights I was there.\nMy room was spacious with a full sea view (Executive Ocean View Room) on the 31st floor. I didn't use any of the facilities (pool, gym, spa etc) so can't comment",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Pooja",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "7.0",
#     "title": "Good",
#     "date": "May 2025",
#     "user_name": "Furio",
#     "user_country": "Italy",
#     "text": "There are no comments available for this review",
#     "lang": "it"
#   },
#   {
#     "score": "7.0",
#     "title": "Good",
#     "date": "May 2025",
#     "user_name": "Parikh",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "اقامة جميلة وللمرة الثانية اسكن في هذا الفندق . فخم . موظفين رائعين موقع مميز خدمات متميزه",
#     "date": "June 2025",
#     "user_name": "عيسى",
#     "user_country": "Saudi Arabia",
#     "text": "موقع الفندق واستقبال رائع  من قبل الموظفين . وخاصة مديرة الاستقبال NIKITA وتوفر الخدمات لاشي",
#     "lang": "ar"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "April 2025",
#     "user_name": "راشد",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Ebrahim",
#     "user_country": "South Africa",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Rahul",
#     "user_country": "United Kingdom",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Sachin",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Karthik",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Bhaskar",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "amazing experience",
#     "date": "June 2025",
#     "user_name": "Kristaps",
#     "user_country": "Latvia",
#     "text": "stuff was amazingly friendly, well educated and very professional sometimes longer wait at elevator",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Nasser",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Anonymous",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Prajosh",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Vandana",
#     "user_country": "United Arab Emirates",
#     "text": "Very cute",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "The Best hotel",
#     "date": "June 2025",
#     "user_name": "Pawel",
#     "user_country": "Poland",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "6.0",
#     "title": "Pleasant",
#     "date": "June 2025",
#     "user_name": "Sethuram",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Satisfying Stay",
#     "date": "June 2025",
#     "user_name": "Sak-ab",
#     "user_country": "Australia",
#     "text": "Spacious rooms. Good facilities. Very good staff and guest relations - always trying to please. Late night check in with some incompetent or untrained staff - didn't appear to be the norm.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Munira",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Paresh",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Very Good",
#     "date": "June 2025",
#     "user_name": "Milan",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Overall great experience except bathroom privacy",
#     "date": "June 2025",
#     "user_name": "Radhakrishnan",
#     "user_country": "India",
#     "text": "Great experience with check in , Check out and service at breakfast Bathroom : glass wall without proper curtain. Even after closing the bathroom door you have more than inch visible. Not suitable for stay for family with kids.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Anita",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "3.0",
#     "title": "Poor",
#     "date": "June 2025",
#     "user_name": "Mohammad",
#     "user_country": "India",
#     "text": "Locatiom I stayed at Trident Hotel with my family, and unfortunately, it was a very disappointing experience. We found cockroaches in the room, which was extremely upsetting, especially considering the hotel’s reputed standard. I informed the hotel management immediately, but to my surprise, no prompt action was taken to resolve the issue. The negligence and lack of concern from the staff caused significant mental distress. It is shocking to see such poor hygiene and an indifferent attitude in a hotel of this category.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Mohamed",
#     "user_country": "United Kingdom",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "7.0",
#     "title": "Good",
#     "date": "May 2025",
#     "user_name": "Prakash",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "Paying a premium rate should come with a consistent and high standard of service. While we enjoyed some aspects of our s",
#     "date": "May 2025",
#     "user_name": "Mohammed",
#     "user_country": "Qatar",
#     "text": "The location of the hotel was perfect for us to explore the surrounding areas with ease. The housekeeping staff were kind, and all our requests were attended to promptly, which we truly appreciated. However, given the reputation and brand of the hotel, a few aspects did not meet expectations:\n* Check-in Experience: It took us 28 minutes to check in, which felt unusually long. During this time, other guests approached the counter with service requests and were attended to immediately, interrupting our process. It would be helpful if the staff ensured a more organized system where ongoing check-ins are prioritized, and others are politely asked to wait.\n* Service Equality: I couldn’t help but notice a difference in attentiveness toward foreign guests compared to others. Every guest, regardless of nationality, deserves equal attention and hospitality—especially at this price point.",
#     "lang": "en-us"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Zaynab",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "May 2025",
#     "user_name": "Arindam",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Divvik",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "May 2025",
#     "user_name": "Munir",
#     "user_country": "Oman",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Kavita",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "June 2025",
#     "user_name": "Mehernosh",
#     "user_country": "India",
#     "text": "I absolutely loved the room and the stunning view—but what truly made our stay exceptional was the outstanding service.\rA special thanks to Pratik, Lokesh, and Vikas at the Club Lounge, and Saurabh and William at the reception, who ensured every detail of our stay was taken care of with warmth and attentiveness. The thoughtful gestures—like surprising our kids with complimentary chocolates and cupcakes—truly elevated our experience.\rEvery staff member we interacted with, from valet parking to security, reception, the welcoming committee, room service, restaurant, and lounge teams, was courteous and genuinely hospitable. Even Dattaram, the attendant at the lobby-level washroom, impressed us with his professionalism and warmth.\rIt’s these little moments and genuine interactions that create lifelong memories. Thank you to the entire team for making our stay so special. The room size could have been bigger, especially the bathroom. It was a bit cramped, not soundproof, and the bathtub was too small to accommodate someone like me!",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "June 2025",
#     "user_name": "Rajesh",
#     "user_country": "India",
#     "text": "Entire staff is professional - helping and polite, cleaniness is top rated and options for gluten & lactose free breakfast, as well!! In the shower space, grab bar is placed too high,  in the bathroom the faucet in the sink is placed a bit off-center, which leads to water splashing, out of sink  - towards base of the faucet!\nAlso, wish they had an option for a harder bed, for the room .",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Ankit",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Kant",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "8.0",
#     "title": "An iconic Mumbai hotel in the perfect location",
#     "date": "April 2025",
#     "user_name": "Lucy",
#     "user_country": "United Kingdom",
#     "text": "The location of the hotel is perfect for exploring Mumbai and the views from the room and pool are incredible. Our room was beautiful and had all the facilities that we could require. The breakfast was also lovely and had extensive options. We also offered room service which was good, and staff on a whole were very friendly and helpful. We did have one issue during our stay that needs addressing. The hotel is geared towards hosting large weddings, and while we understand that these bring in significant income, it is important that other guests are not overlooked. At times, it felt as though we were secondary to the wedding events.\rThe main issue was that my friend wanted to use an outdoor area to smoke while having a drink. There were contradictory instructions from staff about where she could go, which resulted in her either being hidden around the corner from the pool or outside the front lobby where all the cars pull in—without a chair and made to feel like an inconvenience.\rWe queried this with staff and received varying responses, but were eventually told that the pool area is the designated smoking area, although it wasn't always accessible. On those occasions, the facilities and atmosphere fell short of a five-star experience.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Mozah",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "ar"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Ahmed",
#     "user_country": "Oman",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Mataf",
#     "user_country": "Oman",
#     "text": "Great location see facing staff is wonderful everything was wow breakfast is to good Nothing",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "May 2025",
#     "user_name": "Huda",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Aditya",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Vijay",
#     "user_country": "Singapore",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Exceptional",
#     "date": "May 2025",
#     "user_name": "Aakash",
#     "user_country": "United Arab Emirates",
#     "text": "There are no comments available for this review",
#     "lang": "en-us"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "March 2025",
#     "user_name": "Biannka",
#     "user_country": "Australia",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "May 2025",
#     "user_name": "Anirudh",
#     "user_country": "India",
#     "text": "1. Study table was not there. \n2. TV was not working. \n3. Even with AC switched off the room was too cold.",
#     "lang": "en"
#   },
#   {
#     "score": "10",
#     "title": "Iconic Trident",
#     "date": "May 2025",
#     "user_name": "Dya",
#     "user_country": "Mauritius",
#     "text": "The location and the Service and a special mention about Ms Richaa guest Relation associate None",
#     "lang": "en"
#   },
#   {
#     "score": "7.0",
#     "title": "Okay",
#     "date": "May 2025",
#     "user_name": "Mansi",
#     "user_country": "India",
#     "text": "Location Bathroom was small and rooms need to be re done and little more fancy and modern.",
#     "lang": "en"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "April 2025",
#     "user_name": "Lucia",
#     "user_country": "Uruguay",
#     "text": "Excelente ubicación y desayuno, buen servicio de taxi al aeropuerto Todo ok",
#     "lang": "es"
#   },
#   {
#     "score": "9.0",
#     "title": "Wonderful",
#     "date": "April 2025",
#     "user_name": "Vispi",
#     "user_country": "India",
#     "text": "There are no comments available for this review",
#     "lang": "en"
#   }
# ]
